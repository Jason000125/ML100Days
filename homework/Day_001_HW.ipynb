# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 233.226
# The Mean absolute error is 11.791

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# Competition: OSIC Pulmonary Fibrosis Progression - Predict lung function decline
#
# 1. 你選的這組資料為何重要
# A. 在此競賽中，將根據肺部CT掃描影像預測患者肺功能下降的嚴重程度。根據肺活量計(測量吸入和呼出的空氣量)的輸出確定肺功能。如能有效預測可幫助治療或協助預後。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# A. 由OSIC(開源影像協會)提供，收集自公私部門真實的醫學數據。
#
# 3. 蒐集而來的資料型態為何
# A. csv檔:完整的臨床歷史訊息
#    影像檔:DICOM格式的患者baseline CT scan
#
# 4. 這組資料想解決的問題如何評估
# A. 在醫療應用中，評估模型對其決策的信心很有用。因此，度量分數被設計為反映每個預測的準確性和確定性。最終分數是通過對所有測試集（每位患者三項）的指標進行平均計算得出的。指標值將為負，越高越好。
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# A. 提升業績的定義是每日的載客人數增加。假設每位司機每月每日能工作值班的時數固定，但有些時段司機在外跑不易載到客人反而浪費，
#    因此若能預測司機何時出車能載到最多客人，並依據天氣狀況調整司機值勤的時間(例如:下雨客量多，可調整司機來值勤)，應可提升業績。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# A. 從車隊記錄每位司機出車及回車隊時間、載客收據記錄的收入、時間、地點資料
#    外部資料從氣象局取得每日的天氣溫度、紫外線、下雨比例等
#
# 3. 蒐集而來的資料型態為何
# A. 車隊可能是紙本記錄，收據是印刷紙本 以上都需再轉換為數位資料
#    氣象局可從網站取得下載電子檔，但若有必要需用爬蟲取得
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# A. 評估載客人數與司機在外空跑的時段，將這2項指標數值化最大化前者、最小化後者
